# %%
#We can use keyword argument 'marker' to emphasize each point with a specified marker

# %%
import matplotlib.pyplot as plt
import numpy as np

x_points = np.array([12, 17, 15, 9])
y_points = np.array([1, 7, 6, 17])

plt.plot(x_points, y_points, marker='o')
plt.show()

# %%
plt.plot(x_points, y_points, marker='*')
plt.show()

# %%
plt.plot(x_points, y_points, marker='.')
plt.show()

# %%
plt.plot(x_points, y_points, marker=',')
plt.show()

# %%
plt.plot(x_points, y_points, marker='x')
plt.show()

# %%
plt.plot(x_points, y_points, marker='X')
plt.show()

# %%
plt.plot(x_points, y_points, marker='+')
plt.show()

# %%
plt.plot(x_points, y_points, marker='P')
plt.show()

# %%
plt.plot(x_points, y_points, marker='s')
plt.show()

# %%
plt.plot(x_points, y_points, marker='d')
plt.show()

# %%
plt.plot(x_points, y_points, marker='D')
plt.show()
